# %% [markdown]
# <a href="https://colab.research.google.com/github/7rashhi/LB23-weekday/blob/main/OpenAI_30th_Oct_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from openai import OpenAI

# %%
f = open('keys/.openai_api_key.txt')
OPENAI_API_KEY = f.read()
client = OpenAI(api_key=OPENAI_API_KEY)

# %%
client.models.list()
# Out:
# SyncPage[Model](data=[Model(id='gpt-4-turbo', created=1712361441, object='model', owned_by='system'), Model(id='gpt-4-turbo-2024-04-09', created=1712601677, object='model', owned_by='system'), Model(id='tts-1', created=1681940951, object='model', owned_by='openai-internal'), Model(id='tts-1-1106', created=1699053241, object='model', owned_by='system'), Model(id='chatgpt-4o-latest', created=1723515131, object='model', owned_by='system'), Model(id='dall-e-2', created=1698798177, object='model', owned_by='system'), Model(id='whisper-1', created=1677532384, object='model', owned_by='openai-internal'), Model(id='gpt-3.5-turbo-instruct', created=1692901427, object='model', owned_by='system'), Model(id='gpt-4o-mini', created=1721172741, object='model', owned_by='system'), Model(id='gpt-4o-2024-05-13', created=1715368132, object='model', owned_by='system'), Model(id='gpt-3.5-turbo', created=1677610602, object='model', owned_by='openai'), Model(id='gpt-3.5-turbo-0125', created=1706048358, obj
# ...

# %% [markdown]
# # Image Generation

# %%
response = client.images.generate(model="dall-e-2", prompt="A digital image captured of an astronaut who is driving a school bus in garden.",
                                  size="1024x1024", quality="standard",n=1)
image_url = response.data[0].url
print(image_url)
# Out:
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-t0rVpDmrXGzROCSvebafYzUO/user-QPxAYi8cvf6A87JC0kEHzQeD/img-1TNjrFOx0zFAcvLa3bD4SOb0.png?st=2024-10-30T01%3A57%3A06Z&se=2024-10-30T03%3A57%3A06Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=d505667d-d6c1-4a0a-bac7-5c84a87759f8&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-10-30T00%3A17%3A22Z&ske=2024-10-31T00%3A17%3A22Z&sks=b&skv=2024-08-04&sig=NVcEExdaCGFN%2BhiZ/Bnp5UkO2Lp/iV8koz%2BIQxU%2BPik%3D

# %%
import matplotlib.pyplot as plt
from PIL import Image
import requests

def image_from_url(image_url):
    img = Image.open(requests.get(image_url, stream=True).raw)
    return img
img = image_from_url(image_url)
plt.imshow(img)

# %%
import matplotlib.pyplot as plt
from PIL import Image
import requests

def image_from_url(image_url):
    img = Image.open(requests.get(image_url, stream=True).raw)
    return img
img = image_from_url(image_url)
plt.imshow(img)

# %%
import io
original_img = image_from_url(image_url)
img_bytes = io.BytesIO()
original_img.save(img_bytes, format='PNG')
img_bytes = img_bytes.getvalue()

response = client.images.create_variation(image=img_bytes, n=5, size="1024x1024")
response
# Out:
# ImagesResponse(created=1730257284, data=[Image(b64_json=None, revised_prompt=None, url='https://oaidalleapiprodscus.blob.core.windows.net/private/org-t0rVpDmrXGzROCSvebafYzUO/user-QPxAYi8cvf6A87JC0kEHzQeD/img-jP9hNYeAazODjjeMmTaSCyZI.png?st=2024-10-30T02%3A01%3A22Z&se=2024-10-30T04%3A01%3A22Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=d505667d-d6c1-4a0a-bac7-5c84a87759f8&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-10-30T00%3A45%3A34Z&ske=2024-10-31T00%3A45%3A34Z&sks=b&skv=2024-08-04&sig=EsBOPnro5CBO9Y3JRz3oGQTP5Y1EVGeJo9NF3ZMOTFM%3D'), Image(b64_json=None, revised_prompt=None, url='https://oaidalleapiprodscus.blob.core.windows.net/private/org-t0rVpDmrXGzROCSvebafYzUO/user-QPxAYi8cvf6A87JC0kEHzQeD/img-3uX4FlimcaIwhbsfyaIbn76p.png?st=2024-10-30T02%3A01%3A22Z&se=2024-10-30T04%3A01%3A22Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=d505667d-d6c1-4a0a-bac7-5c84a87759f8&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-10-30T00%3A45%3A34Z&ske=2024-10-31T
# ...

# %%
response = client.images.generate(model="dall-e-2", prompt="A peaceful beach with turquoise water and white sand, under a bright blue sky",
                                  size="1024x1024", quality="standard",n=1)
image_url = response.data[0].url
print(image_url)
# Out:
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-t0rVpDmrXGzROCSvebafYzUO/user-QPxAYi8cvf6A87JC0kEHzQeD/img-Cwm5eB1JwCgFKd8QcXWMp5Rl.png?st=2024-10-30T02%3A04%3A41Z&se=2024-10-30T04%3A04%3A41Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=d505667d-d6c1-4a0a-bac7-5c84a87759f8&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-10-30T00%3A16%3A30Z&ske=2024-10-31T00%3A16%3A30Z&sks=b&skv=2024-08-04&sig=kPMObAI6XgaY0GjjmZAXATuIHXTcaFnUfRjdl1GtJIY%3D

# %%
import matplotlib.pyplot as plt
from PIL import Image
import requests

def image_from_url(image_url):
    img = Image.open(requests.get(image_url, stream=True).raw)
    return img
img = image_from_url(image_url)
plt.imshow(img)

# %%
response = client.images.generate(model="dall-e-2", prompt="A cute cat talking with dog",
                                  size="1024x1024", quality="standard",n=1)
image_url = response.data[0].url
print(image_url)
# Out:
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-t0rVpDmrXGzROCSvebafYzUO/user-QPxAYi8cvf6A87JC0kEHzQeD/img-Gua4jNJBVNqXVXhP7SZTvDLl.png?st=2024-10-30T02%3A07%3A00Z&se=2024-10-30T04%3A07%3A00Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=d505667d-d6c1-4a0a-bac7-5c84a87759f8&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-10-30T00%3A18%3A05Z&ske=2024-10-31T00%3A18%3A05Z&sks=b&skv=2024-08-04&sig=98zaBu60OgWnRGc3ZRs54df0M3Z/8379wbXsoqVgIcU%3D
